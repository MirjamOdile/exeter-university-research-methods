# %%
import re             # regular expressions
import os             # access directories
import pandas as pd   # dataframes
from tqdm import tqdm # create progress bar (for i in tqdm(list))
os.chdir('../Data')

# %% [markdown]
# ## Load data

# %%
staff = pd.read_csv('UoE_staff.csv')
staff
# Out:
#                                                 college  \
# 0                                   The Business School
# 1                                   The Business School
# 2                                   The Business School
# 3                                   The Business School
# 4                                   The Business School
# ...                                                 ...
# 4135  College of Social Sciences and International S...
# 4136  College of Social Sciences and International S...
# 4137  College of Social Sciences and International S...
# 4138  College of Social Sciences and International S...
# 4139  College of Social Sciences and International S...
#
#                  department                            name  \
# 0                 Economics           Professor Ian Bateman
# 1                 Economics    Professor Giuseppe Cavaliere
# 2                 Economics  Professor Surajeet Chakravarty
# 3                 Economics      Professor Carlos Cortinhas
# 4                 Economics        Professor James Davidson
# ...                     ...                             ...
# 4135  Strategy and Security                    Tobias Borck
# 4136  Strategy and Security             Maria Chiara Slucca
# 4137  Strategy and Security                   Leanne Fuller
# 4138  Strategy and Security                  Salem Osseiran
# 4139  Strategy and Security                       Noel Trew
#
#                                                    role  \
# 0     Professor of Environmental Economics, Director...
# 1                      Distinguished Research Professor
# 2     Associate Professor in Economics, Director of ...
# 3                      Associate Professor of Economics
# 4                    Emeritus Professor of Econometrics
# ...                                                 ...
# 4135                                        PhD Student
# 4136                                        PhD Student
# 4137                                        PhD Student
# 4138                                        PhD Student
# 4139                                        PhD Student
#
#                                                 profile     namelast  \
# 0     https://business-school.exeter.ac.uk/about/peo...      Bateman
# 1     https://business-school.exeter.ac.uk/about/peo...    Cavaliere
# 2     https://business-school.exeter.ac.uk/about/peo...  Chakravarty
# 3     https://business-school.exeter.ac.uk/about/peo...    Cortinhas
# 4     https://business-school.exeter.ac.uk/about/peo...     Davidson
# ...                                                 ...          ...
# 4135           http://eprofile.exeter.ac.uk/tobiasborck        Borck
# 4136   https://eprofile.exeter.ac.uk/mariachiaraslucca/       Slucca
# 4137        https://eprofile.exeter.ac.uk/leannefuller/       Fuller
# 4138       https://eprofile.exeter.ac.uk/salemosseiran/     Osseiran
# 4139              http://eprofile.exeter.ac.uk/noeltrew         Trew
#
#      namefirst     identifier1            identifier2
# 0          Ian      Bateman, I           Bateman, Ian
# 1     Giuseppe    Cavaliere, G    Cavaliere, Giuseppe
# 2     Surajeet  Chakravarty, S  Chakravarty, Surajeet
# 3       Carlos    Cortinhas, C      Cortinhas, Carlos
# 4        James     Davidson, J        Davidson, James
# ...        ...             ...                    ...
# 4135    Tobias        Borck, T          Borck, Tobias
# 4136     Maria       Slucca, M          Slucca, Maria
# 4137    Leanne       Fuller, L         Fuller, Leanne
# 4138     Salem     Osseiran, S        Osseiran, Salem
# 4139      Noel         Trew, N             Trew, Noel
#
# [4140 rows x 9 columns]

# %%
# Prepare data for matching
staff.identifier1 = staff.identifier1.str.lower()
staff.identifier2 = staff.identifier2.str.lower()
staff.college[staff.college == 'The Business School'] = 'Business School'

# %%
ore = pd.read_csv('ORE_data.csv')
ore['identifiers'] = ore.authors.map(lambda x: x.lower())
ore
# Out:
#                                                      url                 type  \
# 0      https://ore.exeter.ac.uk/repository/handle/108...              article
# 1      https://ore.exeter.ac.uk/repository/handle/108...              article
# 2      https://ore.exeter.ac.uk/repository/handle/108...              article
# 3      https://ore.exeter.ac.uk/repository/handle/108...              article
# 4      https://ore.exeter.ac.uk/repository/handle/108...              article
# ...                                                  ...                  ...
# 22930  https://ore.exeter.ac.uk/repository/handle/108...  thesis/dissertation
# 22931  https://ore.exeter.ac.uk/repository/handle/108...  thesis/dissertation
# 22932  https://ore.exeter.ac.uk/repository/handle/108...  thesis/dissertation
# 22933  https://ore.exeter.ac.uk/repository/handle/108...  thesis/dissertation
# 22934  https://ore.exeter.ac.uk/repository/handle/108...  thesis/dissertation
#
#                                                  college  \
# 0                         College of Medicine and Health
# 1             College of Life and Environmental Sciences
# 2             College of Life and Environmental Sciences
# 3      College of Engineering, Mathematics and Physic...
# 4      College of Social Sciences and International S...
# ...                                                  ...
# 22930                                   Doctoral College
# 22931                                   Doctoral College
# 22932                                   Doctoral College
# 22933                                   Doctoral College
# 22934                                   Doctoral College
#
#                                        department  \
# 0      Institute of Biomedical & Clinical Science
# 1                                     Biosciences
# 2                                      Psychology
# 3                                     Mathematics
# 4                                        Politics
# ...                                           ...
# 22930                             Doctoral Theses
# 22931                             Doctoral Theses
# 22932                             Doctoral Theses
# 22933                             Doctoral Theses
# 22934                             Doctoral Theses
#
#                                                  authors  \
# 0              ['Beall, C', 'Hanna, L', 'Ellacott, KLJ']
# 1            ['Paris, JR', 'Stevens, JR', 'Catchen, JM']
# 2      ['Alsubaie, M', 'Abbbott, R', 'Dunn, BD', 'Dic...
# 3      ['Betterton, RT', 'Broad, LM', 'Tsaneva-Atanas...
# 4                           ['Stokes, D', 'waterman, K']
# ...                                                  ...
# 22930                              ['Micheli, Leonardo']
# 22931                             ['Morgenroth, Thekla']
# 22932                           ['Speidl, Bianka Ágnes']
# 22933                                ['Osborne, Joe M.']
# 22934                              ['Redwood, Morwenna']
#
#            date_accessioned date_issued  \
# 0      2017-04-21T12:08:26Z  2017-09-12
# 1      2017-05-02T12:56:27Z  2017-04-18
# 2      2017-04-25T07:20:32Z  2017-04-23
# 3      2017-04-24T08:18:21Z  2017-03-12
# 4      2017-04-24T09:52:00Z  2017-06-12
# ...                     ...         ...
# 22930  2015-10-19T07:44:00Z  2015-04-30
# 22931  2015-10-19T07:40:40Z  2015-06-26
# 22932  2015-09-29T08:56:09Z  2015-03-02
# 22933  2015-10-14T09:27:11Z  2015-05-08
# 22934  2015-10-15T09:43:55Z  2015-05-29
#
#                                                    title  \
# 0                              CNS targets of adipokines
# 1         Lost in parameter space: A road map for Stacks
# 2      Mechanisms of action in mindfulness-based cogn...
# 3      Acetylcholine modulates gamma frequency oscill...
# 4      Beyond balancing? Intrastate conflict and US g...
# ...                                                  ...
# 22930  Enhancing Electrical and Heat Transfer Perform...
# 22931  How Role Models Affect Role Aspirants’ Motivat...
# 22932  Conceptualisation of Power in the Thought of M...
# 22933  Understanding Northern Hemisphere land precipi...
# 22934  Insider Perspectives of Education, Health and ...
#
#                                                 abstract  \
# 0      Our understanding of adipose tissue as an endo...
# 1      1.Restriction site-Associated DNA sequencing (...
# 2      Background\r\n\r\nRecently, there has been an ...
# 3      Modulation of gamma oscillations is important ...
# 4      Grand strategic theorists share an historical ...
# ...                                                  ...
# 22930  In a world that is constantly in need of a con...
# 22931  Role models are often suggested as a means of ...
# 22932  The topic of my research is the Shi'i jurist M...
# 22933  Water is key to life on Earth. The distributio...
# 22934  The introduction of Education, Health and Care...
#
#                                                    doi  \
# 0                                 10.1002/cphy.c160045
# 1                              10.1111/2041-210X.12775
# 2             http://doi.org/10.1016/j.cpr.2017.04.008
# 3                                    10.1111/ejn.13582
# 4      http://dx.doi.org/10.1080/01402390.2017.1330682
# ...                                                ...
# 22930                                              NaN
# 22931                                              NaN
# 22932                                              NaN
# 22933                                              NaN
# 22934                                              NaN
#
#                                              identifiers
# 0              ['beall, c', 'hanna, l', 'ellacott, klj']
# 1            ['paris, jr', 'stevens, jr', 'catchen, jm']
# 2      ['alsubaie, m', 'abbbott, r', 'dunn, bd', 'dic...
# 3      ['betterton, rt', 'broad, lm', 'tsaneva-atanas...
# 4                           ['stokes, d', 'waterman, k']
# ...                                                  ...
# 22930                              ['micheli, leonardo']
# 22931                             ['morgenroth, thekla']
# 22932                           ['speidl, bianka ágnes']
# 22933                                ['osborne, joe m.']
# 22934                              ['redwood, morwenna']
#
# [22935 rows x 11 columns]

# %%
# Check proportion of missing information in the ORE data
(ore.isnull().sum()*100/len(ore)).round(1)
# Out:
# url                  0.0
# type                 0.0
# college              0.0
# department           0.0
# authors              0.0
# date_accessioned     0.0
# date_issued          0.0
# title                0.0
# abstract             5.5
# doi                 14.4
# identifiers          0.0
# dtype: float64

# %%
# Check which colleges in the ORE data do not match the staff data
for col in ore.college.unique():
    if not col in staff.college.unique():
     print(col)
# Out:
# Other Collections
# Doctoral College
# Special Collections

# %%
# Check which department in the ORE data do not match the staff data
for dep in ore.department.unique():
    if not dep in staff.department.unique():
     print(dep)
# Out:
# Institute of Biomedical & Clinical Science
# Institute of Health Research
# Management Studies
# Sociology, Philosophy & Anthropology
# Russian
# Organisation Studies
# Accounting
# Chinese
# German
# Institute of Medical Education
# Portuguese
# Italian
# French
# Hispanic Studies
# Medical Imaging
# Professional Services
# European Centre for Environment & Human Health
# University of Exeter Journals
# Collections of Former Colleges
# Conferences@Exeter
# Doctoral Theses
# De-placing Future Memory Research Project
# Arab World Documentation Unit
# MbyRes Dissertations
# Bill Douglas Cinema Museum
# Open Exeter Project
# MPhil Dissertations

# %%
for dep in staff.department.unique():
    if not dep in ore.department.unique():
     print(dep)
# Out:
# Finance and Accounting
# Management
# Sustainable Futures
# Business School PGR
# EMPS
# Renewable Energy
# Mathematics Exeter (Mods & Progs Only)
# Mathematics Penryn (Mods & Progs Only)
# Art History & Visual Culture
# Film Studies
# Liberal Arts
# Modern Languages
# Medicine and Health
# Sociology, Philosophy and Anthropology
# Strategy and Security

# %% [markdown]
# ## Match staff members to metadata

# %%
# %%time
# # Match by department
# authors = []
# dates = []
# titles = []
# abstracts = []
# urls = []
# fields = []
# publications = []

# for i, name in enumerate(staff.name):
#     authors_temp = []
#     dates_temp = []
#     titles_temp = []
#     abstracts_temp = []
#     url_temp = []
#     field_temp = []
#     count = 0
#     for j, title in enumerate(ore.title):
#         if ((staff.identifier1[i] in ore.identifiers[j]) or (staff.identifier2[i] in ore.identifiers[j])) and staff.college[i] in ore.college[j]:
#             authors_temp.append(ore.authors[j])
#             dates_temp.append(ore.date_issued[j])
#             titles_temp.append(ore.title[j])
#             abstracts_temp.append(ore.abstract[j])
#             url_temp.append(ore.url[j])
#             field_temp.append(ore.department[j])
#             count +=1
#     publications.append(count)
#     authors.append(authors_temp)
#     dates.append(dates_temp)
#     titles.append(titles_temp)
#     abstracts.append(abstracts_temp)
#     urls.append(url_temp) 
#     fields.append(field_temp)

# %%
# %%time
# Match by name and college
authors = []
dates = []
titles = []
abstracts = []
urls = []
fields = []
types = []
publications = []

for i, name in enumerate(staff.name):
    authors_temp = []
    dates_temp = []
    titles_temp = []
    abstracts_temp = []
    url_temp = []
    field_temp = []
    type_temp = []
    count = 0
    for j, title in enumerate(ore.title):
        if ((staff.identifier1[i] in ore.identifiers[j]) or (staff.identifier2[i] in ore.identifiers[j])) and (staff.college[i] in ore.college[j] or ore.college[j] == "Doctoral College"):
            authors_temp.append(ore.authors[j])
            dates_temp.append(ore.date_issued[j])
            titles_temp.append(ore.title[j])
            abstracts_temp.append(ore.abstract[j])
            url_temp.append(ore.url[j])
            field_temp.append(ore.department[j])
            type_temp.append(ore.type[j])
            count +=1
    publications.append(count)
    authors.append(authors_temp)
    dates.append(dates_temp)
    titles.append(titles_temp)
    abstracts.append(abstracts_temp)
    urls.append(url_temp) 
    fields.append(field_temp)
    types.append(type_temp)
# Out:
# CPU times: user 1h 33min 51s, sys: 4.92 s, total: 1h 33min 56s
# Wall time: 1h 33min 59s

# %%
df = pd.concat([staff.reset_index(drop=True), 
                pd.DataFrame(list(zip(publications, authors, dates, titles, abstracts, urls, fields, types)),
                             columns=['publications', 'authors', 'dates', 'titles', 'abstracts', 'urls', 'fields', 'types'])] , axis = 1)
df
# Out:
#                                                 college  \
# 0                                       Business School
# 1                                       Business School
# 2                                       Business School
# 3                                       Business School
# 4                                       Business School
# ...                                                 ...
# 4135  College of Social Sciences and International S...
# 4136  College of Social Sciences and International S...
# 4137  College of Social Sciences and International S...
# 4138  College of Social Sciences and International S...
# 4139  College of Social Sciences and International S...
#
#                  department                            name  \
# 0                 Economics           Professor Ian Bateman
# 1                 Economics    Professor Giuseppe Cavaliere
# 2                 Economics  Professor Surajeet Chakravarty
# 3                 Economics      Professor Carlos Cortinhas
# 4                 Economics        Professor James Davidson
# ...                     ...                             ...
# 4135  Strategy and Security                    Tobias Borck
# 4136  Strategy and Security             Maria Chiara Slucca
# 4137  Strategy and Security                   Leanne Fuller
# 4138  Strategy and Security                  Salem Osseiran
# 4139  Strategy and Security                       Noel Trew
#
#                                                    role  \
# 0     Professor of Environmental Economics, Director...
# 1                      Distinguished Research Professor
# 2     Associate Professor in Economics, Director of ...
# 3                      Associate Professor of Economics
# 4                    Emeritus Professor of Econometrics
# ...                                                 ...
# 4135                                        PhD Student
# 4136                                        PhD Student
# 4137                                        PhD Student
# 4138                                        PhD Student
# 4139                                        PhD Student
#
#                                                 profile     namelast  \
# 0     https://business-school.exeter.ac.uk/about/peo...      Bateman
# 1     https://business-school.exeter.ac.uk/about/peo...    Cavaliere
# 2     https://business-school.exeter.ac.uk/about/peo...  Chakravarty
# 3     https://business-school.exeter.ac.uk/about/peo...    Cortinhas
# 4     https://business-school.exeter.ac.uk/about/peo...     Davidson
# ...                                                 ...          ...
# 4135           http://eprofile.exeter.ac.uk/tobiasborck        Borck
# 4136   https://eprofile.exeter.ac.uk/mariachiaraslucca/       Slucca
# 4137        https://eprofile.exeter.ac.uk/leannefuller/       Fuller
# 4138       https://eprofile.exeter.ac.uk/salemosseiran/     Osseiran
# 4139              http://eprofile.exeter.ac.uk/noeltrew         Trew
#
#      namefirst     identifier1            identifier2  publications  \
# 0          Ian      bateman, i           bateman, ian            40
# 1     Giuseppe    cavaliere, g    cavaliere, giuseppe             8
# 2     Surajeet  chakravarty, s  chakravarty, surajeet            12
# 3       Carlos    cortinhas, c      cortinhas, carlos             1
# 4        James     davidson, j        davidson, james            25
# ...        ...             ...                    ...           ...
# 4135    Tobias        borck, t          borck, tobias             0
# 4136     Maria       slucca, m          slucca, maria             0
# 4137    Leanne       fuller, l         fuller, leanne             0
# 4138     Salem     osseiran, s        osseiran, salem             0
# 4139      Noel         trew, n             trew, noel             0
#
#                                                 authors  \
# 0     [['Fezzi, Carlo', 'Bateman, IJ'], ['Bateman, I...
# 1     [['Boswijk, HO', 'Cavaliere, G', 'Georgiev, I'...
# 2     [['Chakravarty, S', 'Fonseca, MA', 'Ghosh, S',...
# 3                               [['Cortinhas, Carlos']]
# 4     [['Davidson, James', 'Rambaccussing, Dooruj'],...
# ...                                                 ...
# 4135                                                 []
# 4136                                                 []
# 4137                                                 []
# 4138                                                 []
# 4139                                                 []
#
#                                                   dates  \
# 0     [2015-02-04, 2013-10-25, 2014-01-08, 2013-07-0...
# 1     [2021-03-04, 2020-09-15, 2020-11-30, 2018-06-1...
# 2     [2016-10-21, 2016-11-01, 2016-03-16, 2015-01, ...
# 3                                             [2007-04]
# 4     [2015-05-30, 2016-09-01, 2015-09-05, 2000-10, ...
# ...                                                 ...
# 4135                                                 []
# 4136                                                 []
# 4137                                                 []
# 4138                                                 []
# 4139                                                 []
#
#                                                  titles  \
# 0     [The Impact of Climate Change on Agriculture: ...
# 1     [Bootstrapping non-stationary stochastic volat...
# 2     [Religious fragmentation, social identity and ...
# 3     [Intra-industry trade and business cycles in A...
# 4     [A test of the long memory hypothesis based on...
# ...                                                 ...
# 4135                                                 []
# 4136                                                 []
# 4137                                                 []
# 4138                                                 []
# 4139                                                 []
#
#                                               abstracts  \
# 0     [Ricardian (hedonic) analyses of the impact of...
# 1     [In this paper we investigate to what extent t...
# 2     [We examine the impact of religious identity a...
# 3     [A new resolve for both increased economic int...
# 4     [This paper develops a new test of true versus...
# ...                                                 ...
# 4135                                                 []
# 4136                                                 []
# 4137                                                 []
# 4138                                                 []
# 4139                                                 []
#
#                                                    urls  \
# 0     [https://ore.exeter.ac.uk/repository/handle/10...
# 1     [https://ore.exeter.ac.uk/repository/handle/10...
# 2     [https://ore.exeter.ac.uk/repository/handle/10...
# 3     [https://ore.exeter.ac.uk/repository/handle/10...
# 4     [https://ore.exeter.ac.uk/repository/handle/10...
# ...                                                 ...
# 4135                                                 []
# 4136                                                 []
# 4137                                                 []
# 4138                                                 []
# 4139                                                 []
#
#                                                  fields  \
# 0     [Economics, Economics, Economics, Economics, E...
# 1     [Economics, Economics, Economics, Economics, E...
# 2     [Economics, Economics, Economics, Economics, E...
# 3                                           [Economics]
# 4     [Economics, Economics, Economics, Economics, E...
# ...                                                 ...
# 4135                                                 []
# 4136                                                 []
# 4137                                                 []
# 4138                                                 []
# 4139                                                 []
#
#                                                   types
# 0     [article, article, article, article, article, ...
# 1     [article, article, article, article, article, ...
# 2     [article, article, article, article, article, ...
# 3                                             [article]
# 4     [article, article, article, article, article, ...
# ...                                                 ...
# 4135                                                 []
# 4136                                                 []
# 4137                                                 []
# 4138                                                 []
# 4139                                                 []
#
# [4140 rows x 17 columns]

# %%
# Manually fix wrong matches for authors with 40+ publications

# # Ali A
# df.loc[1243,'authors':'types'] = df.loc[1243,'authors':'types'].apply(lambda x: list())
# df.loc[1243,'publications'] = len(df.loc[1243,'authors'])

# # Rod and Robert Taylor
# taylor_robert = []
# taylor_rod = []
# for i, authors in enumerate(df.loc[3245]['authors']):
#     if len(re.findall("Taylor, Robert|Taylor, R'|Taylor, RW", authors)) != 0:
#         taylor_robert.append(i)
#     if len(re.findall("Taylor, Rod S|Taylor, RS", authors)) != 0:
#         taylor_rod.append(i)
# df.loc[3245,'authors':'types'] = df.loc[3245,'authors':'types'].apply(lambda x: [x[i] for i in taylor_rod])
# df.loc[3245,'publications'] = len(df.loc[3245,'authors'])
# df.loc[3246,'authors':'types'] = df.loc[3246,'authors':'types'].apply(lambda x: [x[i] for i in taylor_robert])
# df.loc[3246,'publications'] = len(df.loc[3246,'authors'])

# Yang, Yaan, and Yinchen Liu
# liu_yang = []
# liu_yaan = []
# for i, authors in enumerate(df.loc[443]['authors']):
#     # All of Yaan Liu's articles are coauthored with Ghita
#     if len(re.findall("Ghita", authors)) != 0:
#         liu_yaan.append(i)
#     else:
#         liu_yang.append(i)
# df.loc[443,'authors':'types'] = df.loc[443,'authors':'types'].apply(lambda x: [x[i] for i in liu_yang])
# df.loc[443,'publications'] = len(df.loc[443,'authors'])
# df.loc[737,'authors':'types'] = df.loc[737,'authors':'types'].apply(lambda x: [x[i] for i in liu_yaan])
# df.loc[737,'publications'] = len(df.loc[737,'authors'])
# df.loc[1525,'authors':'types'] = df.loc[1525,'authors':'types'].apply(lambda x: list())
# df.loc[1525,'publications'] = len(df.loc[1525,'authors'])

# # Craig and C. David Wright
# wright_c_david = []
# for i, authors in enumerate(df.loc[477]['authors']):
#     if len(re.findall("Wright, C. David|Wright, CD|Wright, C'|David Wright, C", authors)) != 0:
#         wright_c_david.append(i)
# df.loc[477,'authors':'types'] = df.loc[477,'authors':'types'].apply(lambda x: [x[i] for i in wright_c_david])
# df.loc[477,'publications'] = len(df.loc[477,'authors'])
# df.loc[1065,'authors':'types'] = df.loc[1065,'authors':'types'].apply(lambda x: list())
# df.loc[1065,'publications'] = len(df.loc[1065,'authors'])

# # Hani Y
# df.loc[2827,'authors':'types'] = df.loc[2827,'authors':'types'].apply(lambda x: list())
# df.loc[2827,'publications'] = len(df.loc[2827,'authors'])

# # Xinqi and Xiang Li
# df.loc[675,'authors':'types'] = df.loc[675,'authors':'types'].apply(lambda x: list())
# df.loc[675,'publications'] = len(df.loc[675,'authors'])
# df.loc[1524,'authors':'types'] = df.loc[1524,'authors':'types'].apply(lambda x: list())
# df.loc[1524,'publications'] = len(df.loc[1524,'authors'])

# # Yuxiao, Yi, and Ying Wang
# wang_ying = []
# for i, authors in enumerate(df.loc[762]['authors']):
#     # All of Ying Wang's articles are coauthored with Dai, K
#     if len(re.findall("Dai, K", authors)) != 0:
#         wang_ying.append(i)     
# df.loc[762,'authors':'types'] = df.loc[762,'authors':'types'].apply(lambda x: [x[i] for i in wang_ying])
# df.loc[762,'publications'] = len(df.loc[762,'authors'])
# df.loc[1224,'authors':'types'] = df.loc[1224,'authors':'types'].apply(lambda x: list())
# df.loc[1224,'publications'] = len(df.loc[1224,'authors'])
# df.loc[1353,'authors':'types'] = df.loc[1353,'authors':'types'].apply(lambda x: list())
# df.loc[1353,'publications'] = len(df.loc[1353,'authors'])

# Yujia Zhu
# df.loc[1080,'authors':'types'] = df.loc[1080,'authors':'types'].apply(lambda x: list())
# df.loc[1080,'publications'] = len(df.loc[1080,'authors'])

# # Sarah Bell and Sian de Bell
# bell_sarah = []
# debell_sian = []
# for i, authors in enumerate(df.loc[2855]['authors']):
#     if len(re.findall("Bell, SL|Bell, Sarah L|^Bell, S", authors)) != 0:
#         bell_sarah.append(i)
#     elif len(re.findall("de Bell", authors)) != 0:
#         debell_sian.append(i)
# df.loc[2855,'authors':'types'] = df.loc[2855,'authors':'types'].apply(lambda x: [x[i] for i in bell_sarah])
# df.loc[2855,'publications'] = len(df.loc[2855,'authors'])
# df.loc[2919,'authors':'types'] = df.loc[2919,'authors':'types'].apply(lambda x: [x[i] for i in debell_sian])
# df.loc[2919,'publications'] = len(df.loc[2919,'authors'])

# # Rebecca and Richard Smith
# smith_rebecca = []
# smith_richard = []
# for i, authors in enumerate(df.loc[3224]['authors']):
#     if len(re.findall("Smith, RG|Smith, Rebecca", authors)) != 0:
#         smith_rebecca.append(i)
#     elif len(re.findall("Smith, R'|Smith, RD", authors)) != 0:
#         smith_richard.append(i)
# df.loc[3224,'authors':'types'] = df.loc[3224,'authors':'types'].apply(lambda x: [x[i] for i in smith_rebecca])
# df.loc[3224,'publications'] = len(df.loc[3224,'authors'])
# df.loc[3225,'authors':'types'] = df.loc[3225,'authors':'types'].apply(lambda x: [x[i] for i in smith_richard])
# df.loc[3225,'publications'] = len(df.loc[3225,'authors'])

# %%
# Manually fix wrong matches for authors with 30+ publications

# Abigail and Anne-Marie Russell
russell_abigail = []
russell_anne = []
for i, authors in enumerate(df.loc[3201]['authors']):
    if len(re.findall("Russell, AM|Russell, A-M", authors)) != 0:
        russell_anne.append(i)
    else:
        russell_abigail.append(i)
df.loc[3201,'authors':'types'] = df.loc[3201,'authors':'types'].apply(lambda x: [x[i] for i in russell_abigail])
df.loc[3201,'publications'] = len(df.loc[3201,'authors'])
df.loc[3202,'authors':'types'] = df.loc[3202,'authors':'types'].apply(lambda x: [x[i] for i in russell_anne])
df.loc[3202,'publications'] = len(df.loc[3202,'authors'])

# Ali A
df.loc[1243,'authors':'types'] = df.loc[1243,'authors':'types'].apply(lambda x: list())
df.loc[1243,'publications'] = len(df.loc[1243,'authors'])

# Aimee and Anna Murray
murray_aimee = []
murray_anna = []
for i, authors in enumerate(df.loc[3125]['authors']):
    if len(re.findall("Murray, AK|Bendall, R", authors)) != 0:
        murray_aimee.append(i)
    else:
        murray_anna.append(i)
df.loc[3125,'authors':'types'] = df.loc[3125,'authors':'types'].apply(lambda x: [x[i] for i in murray_aimee])
df.loc[3125,'publications'] = len(df.loc[3125,'authors'])
df.loc[3126,'authors':'types'] = df.loc[3126,'authors':'types'].apply(lambda x: [x[i] for i in murray_anna])
df.loc[3126,'publications'] = len(df.loc[3126,'authors'])

# Chao and Chi Zhang
df.loc[1074,'authors':'types'] = df.loc[1074,'authors':'types'].apply(lambda x: list())
df.loc[1074,'publications'] = len(df.loc[1074,'authors'])
df.loc[1239,'authors':'types'] = df.loc[1239,'authors':'types'].apply(lambda x: list())
df.loc[1239,'publications'] = len(df.loc[1239,'authors'])

# Craig and C. David Wright
wright_c_david = []
for i, authors in enumerate(df.loc[477]['authors']):
    if len(re.findall("Wright, C. David|Wright, CD|Wright, C'|David Wright, C", authors)) != 0:
        wright_c_david.append(i)
df.loc[477,'authors':'types'] = df.loc[477,'authors':'types'].apply(lambda x: [x[i] for i in wright_c_david])
df.loc[477,'publications'] = len(df.loc[477,'authors'])
df.loc[1065,'authors':'types'] = df.loc[1065,'authors':'types'].apply(lambda x: list())
df.loc[1065,'publications'] = len(df.loc[1065,'authors'])

# Daniel and Derek Partridge
partridge_daniel = []
partridge_derek = []
for i, authors in enumerate(df.loc[540]['authors']):
    if len(re.findall("Partridge, Derek", authors)) != 0:
        partridge_derek.append(i)
    else:
        partridge_daniel.append(i)
df.loc[540,'authors':'types'] = df.loc[540,'authors':'types'].apply(lambda x: [x[i] for i in partridge_daniel])
df.loc[540,'publications'] = len(df.loc[540,'authors'])
df.loc[1569,'authors':'types'] = df.loc[1569,'authors':'types'].apply(lambda x: [x[i] for i in partridge_derek])
df.loc[1569,'publications'] = len(df.loc[1569,'authors'])

# Hani Y
df.loc[2827,'authors':'types'] = df.loc[2827,'authors':'types'].apply(lambda x: list())
df.loc[2827,'publications'] = len(df.loc[2827,'authors'])

# Junhao, Jingyi and Jin Wang
wang_jin = []
for i, titles in enumerate(df.loc[1059]['titles']):
    if len(re.findall("Data Augmentation|Learning", titles)) != 0:
        wang_jin.append(i)
df.loc[1059,'authors':'types'] = df.loc[1059,'authors':'types'].apply(lambda x: [x[i] for i in wang_jin])
df.loc[1059,'publications'] = len(df.loc[1059,'authors'])
df.loc[1108,'authors':'types'] = df.loc[1108,'authors':'types'].apply(lambda x: list())
df.loc[1108,'publications'] = len(df.loc[1108,'authors'])
df.loc[1225,'authors':'types'] = df.loc[1225,'authors':'types'].apply(lambda x: list())
df.loc[1225,'publications'] = len(df.loc[1225,'authors'])

# Katrina and Kerry Brown
brown_katrina = []
brown_kerry = []
junk = []
for i, authors in enumerate(df.loc[2485]['authors']):
    if len(re.findall("Adger|Baggio|Chaigneau|Galafassi|Huke|Morrison|Quinn|Schoon", authors)) != 0 or authors == "['Brown, K']":
        brown_katrina.append(i)
    elif len(re.findall("Venkateshmurthy", authors)) != 0:
        brown_kerry.append(i)
df.loc[2485,'authors':'types'] = df.loc[2485,'authors':'types'].apply(lambda x: [x[i] for i in brown_katrina])
df.loc[2485,'publications'] = len(df.loc[2485,'authors'])
df.loc[2698,'authors':'types'] = df.loc[2698,'authors':'types'].apply(lambda x: [x[i] for i in brown_kerry])
df.loc[2698,'publications'] = len(df.loc[2698,'authors'])

# Rebecca and Richard Smith
smith_rebecca = []
smith_richard = []
for i, authors in enumerate(df.loc[3224]['authors']):
    if len(re.findall("Smith, RG|Smith, Rebecca", authors)) != 0:
        smith_rebecca.append(i)
    elif len(re.findall("Smith, R'|Smith, RD", authors)) != 0:
        smith_richard.append(i)
df.loc[3224,'authors':'types'] = df.loc[3224,'authors':'types'].apply(lambda x: [x[i] for i in smith_rebecca])
df.loc[3224,'publications'] = len(df.loc[3224,'authors'])
df.loc[3225,'authors':'types'] = df.loc[3225,'authors':'types'].apply(lambda x: [x[i] for i in smith_richard])
df.loc[3225,'publications'] = len(df.loc[3225,'authors'])

# Rod and Robert Taylor
taylor_robert = []
taylor_rod = []
for i, authors in enumerate(df.loc[3245]['authors']):
    if len(re.findall("Taylor, Robert|Taylor, R'|Taylor, RW", authors)) != 0:
        taylor_robert.append(i)
    if len(re.findall("Taylor, Rod S|Taylor, RS", authors)) != 0:
        taylor_rod.append(i)
df.loc[3245,'authors':'types'] = df.loc[3245,'authors':'types'].apply(lambda x: [x[i] for i in taylor_rod])
df.loc[3245,'publications'] = len(df.loc[3245,'authors'])
df.loc[3246,'authors':'types'] = df.loc[3246,'authors':'types'].apply(lambda x: [x[i] for i in taylor_robert])
df.loc[3246,'publications'] = len(df.loc[3246,'authors'])

# Sarah Bell and Sian de Bell
bell_sarah = []
debell_sian = []
for i, authors in enumerate(df.loc[2855]['authors']):
    if len(re.findall("Bell, SL|Bell, Sarah L|^Bell, S", authors)) != 0:
        bell_sarah.append(i)
    elif len(re.findall("de Bell", authors)) != 0:
        debell_sian.append(i)
df.loc[2855,'authors':'types'] = df.loc[2855,'authors':'types'].apply(lambda x: [x[i] for i in bell_sarah])
df.loc[2855,'publications'] = len(df.loc[2855,'authors'])
df.loc[2919,'authors':'types'] = df.loc[2919,'authors':'types'].apply(lambda x: [x[i] for i in debell_sian])
df.loc[2919,'publications'] = len(df.loc[2919,'authors'])

# Sigong Zhang
df.loc[767,'authors':'types'] = df.loc[767,'authors':'types'].apply(lambda x: list())
df.loc[767,'publications'] = len(df.loc[767,'authors'])

# Yang, Yaan, and Yinchen Liu
liu_yang = []
liu_yaan = []
for i, authors in enumerate(df.loc[443]['authors']):
    # All of Yaan Liu's articles are coauthored with Ghita
    if len(re.findall("Ghita", authors)) != 0:
        liu_yaan.append(i)
    else:
        liu_yang.append(i)
df.loc[443,'authors':'types'] = df.loc[443,'authors':'types'].apply(lambda x: [x[i] for i in liu_yang])
df.loc[443,'publications'] = len(df.loc[443,'authors'])
df.loc[737,'authors':'types'] = df.loc[737,'authors':'types'].apply(lambda x: [x[i] for i in liu_yaan])
df.loc[737,'publications'] = len(df.loc[737,'authors'])
df.loc[1525,'authors':'types'] = df.loc[1525,'authors':'types'].apply(lambda x: list())
df.loc[1525,'publications'] = len(df.loc[1525,'authors'])

# Yujia Zhu
df.loc[1080,'authors':'types'] = df.loc[1080,'authors':'types'].apply(lambda x: list())
df.loc[1080,'publications'] = len(df.loc[1080,'authors'])

# Yuxiao, Yi, and Ying Wang
wang_ying = []
for i, authors in enumerate(df.loc[762]['authors']):
    # All of Ying Wang's articles are coauthored with Dai, K
    if len(re.findall("Dai, K", authors)) != 0:
        wang_ying.append(i)     
df.loc[762,'authors':'types'] = df.loc[762,'authors':'types'].apply(lambda x: [x[i] for i in wang_ying])
df.loc[762,'publications'] = len(df.loc[762,'authors'])
df.loc[1224,'authors':'types'] = df.loc[1224,'authors':'types'].apply(lambda x: list())
df.loc[1224,'publications'] = len(df.loc[1224,'authors'])
df.loc[1353,'authors':'types'] = df.loc[1353,'authors':'types'].apply(lambda x: list())
df.loc[1353,'publications'] = len(df.loc[1353,'authors'])

# Xinqi and Xiang Li
df.loc[675,'authors':'types'] = df.loc[675,'authors':'types'].apply(lambda x: list())
df.loc[675,'publications'] = len(df.loc[675,'authors'])
df.loc[1524,'authors':'types'] = df.loc[1524,'authors':'types'].apply(lambda x: list())
df.loc[1524,'publications'] = len(df.loc[1524,'authors'])

# %%
# A lot of duplicates remain, but these are too many to fix manually
df[(df.duplicated(subset=['namelast', 'publications'], keep = False)) & (df.publications>0) ].sort_values(by=['publications', 'namelast'])
# Out:
#                                                 college  \
# 1082  College of Engineering, Mathematics and Physic...
# 1365  College of Engineering, Mathematics and Physic...
# 696   College of Engineering, Mathematics and Physic...
# 1122  College of Engineering, Mathematics and Physic...
# 2292         College of Life and Environmental Sciences
# ...                                                 ...
# 1730                              College of Humanities
# 465   College of Engineering, Mathematics and Physic...
# 3225                     College of Medicine and Health
# 838   College of Engineering, Mathematics and Physic...
# 913   College of Engineering, Mathematics and Physic...
#
#                         department                            name  \
# 1082                          EMPS          Manal Safar G Alghamdi
# 1365         Physics and Astronomy        Mashael Saeed S Alghamdi
# 696                    Engineering                  Priscila Alves
# 1122                   Engineering   Priscila Barros Ramalho Alves
# 2292                   Biosciences                  Dr David Baker
# ...                            ...                             ...
# 1730  Classics and Ancient History        Professor Neville Morley
# 465                    Engineering     Professor Christopher Smith
# 3225           Medicine and Health         Professor Richard Smith
# 838                    Mathematics                    Dr Chen Wang
# 913          Physics and Astronomy               Dr Chun-Chin Wang
#
#                                                    role  \
# 1082                                                NaN
# 1365                                       Postgraduate
# 696                     Postdoctoral Research Associate
# 1122                            Postgraduate Researcher
# 2292                                    Research Fellow
# ...                                                 ...
# 1730                                                NaN
# 465                 Professor of Mechanical Engineering
# 3225  Deputy Pro-Vice Chancellor and Professor of He...
# 838                        Postdoctoral Research Fellow
# 913                                     Research Fellow
#
#                                                 profile  namelast  \
# 1082            https://emps.exeter.ac.uk/staff/mmma201  Alghamdi
# 1365  https://emps.exeter.ac.uk/physics-astronomy/st...  Alghamdi
# 696   https://emps.exeter.ac.uk/engineering/staff/pa361     Alves
# 1122  https://emps.exeter.ac.uk/engineering/staff/pr327     Alves
# 2292  https://biosciences.exeter.ac.uk/staff/profile...     Baker
# ...                                                 ...       ...
# 1730  https://humanities.exeter.ac.uk/classics/staff...    Morley
# 465   https://emps.exeter.ac.uk/engineering/staff/cw...     Smith
# 3225  https://medicine.exeter.ac.uk/people/profile/i...     Smith
# 838   https://emps.exeter.ac.uk/mathematics/staff/cw880      Wang
# 913   https://emps.exeter.ac.uk/physics-astronomy/st...      Wang
#
#         namefirst  identifier1         identifier2  publications  \
# 1082        Manal  alghamdi, m     alghamdi, manal             1
# 1365      Mashael  alghamdi, m   alghamdi, mashael             1
# 696      Priscila     alves, p     alves, priscila             1
# 1122     Priscila     alves, p     alves, priscila             1
# 2292        David     baker, d        baker, david             1
# ...           ...          ...                 ...           ...
# 1730      Neville    morley, n     morley, neville            25
# 465   Christopher     smith, c  smith, christopher            26
# 3225      Richard     smith, r      smith, richard            26
# 838          Chen      wang, c          wang, chen            30
# 913     Chun-Chin      wang, c     wang, chun-chin            30
#
#                                                 authors  \
# 1082  [['Nasir, SNFM', 'Ullah, H', 'Mutalib, MA', 'S...
# 1365  [['Nasir, SNFM', 'Ullah, H', 'Mutalib, MA', 'S...
# 696   [['Barros Ramalho Alves, P', 'Alves Rufino, IA...
# 1122  [['Barros Ramalho Alves, P', 'Alves Rufino, IA...
# 2292  [['Turchin, P', 'Currie, TE', 'Whitehouse, H',...
# ...                                                 ...
# 1730  [['Morley, NDG'], ['Morley, NDG'], ['Morley, N...
# 465   [['Amundsen, DS', 'Mayne, NJ', 'Baraffe, I', '...
# 3225  [['Reis, S', 'Steinle, S', 'Morris, G', 'Flemi...
# 838   [['Zheng, G', 'Chu, C', 'Belavý, DL', 'Ibragim...
# 913   [['Zheng, G', 'Chu, C', 'Belavý, DL', 'Ibragim...
#
#                                                   dates  \
# 1082                                       [2021-12-07]
# 1365                                       [2021-12-07]
# 696                                        [2020-01-16]
# 1122                                       [2020-01-16]
# 2292                                       [2018-01-09]
# ...                                                 ...
# 1730  [2017-11-01, 2017-09-27, 2020, 2020-02-21, 201...
# 465   [2016-08-26, 2015-11-15, 2015-01-01, 2018-01-0...
# 3225  [2013-10-04, 2016-06-06, 2017-10-16, 2018-04-2...
# 838   [2016-08-17, 2017-05-11, 2016-06, 2016-09-07, ...
# 913   [2016-08-17, 2017-05-11, 2016-06, 2016-09-07, ...
#
#                                                  titles  \
# 1082  [WTa37O95.487 Nanocatalyst for Pollutant Degra...
# 1365  [WTa37O95.487 Nanocatalyst for Pollutant Degra...
# 696   [Land-Use and Legislation-Based Methodology fo...
# 1122  [Land-Use and Legislation-Based Methodology fo...
# 2292  [Quantitative historical analysis uncovers a s...
# ...                                                 ...
# 1730  [History Can't Always Help to Make Sense of th...
# 465   [The UK Met Office GCM with a sophisticated ra...
# 3225  [Integrating Health & Environmental Impact Ana...
# 838   [Evaluation and comparison of 3D intervertebra...
# 913   [Evaluation and comparison of 3D intervertebra...
#
#                                               abstracts  \
# 1082  [The release of toxic industrial effluents has...
# 1365  [The release of toxic industrial effluents has...
# 696   [In developing countries, the urbanisation pro...
# 1122  [In developing countries, the urbanisation pro...
# 2292  [Do human societies from around the world exhi...
# ...                                                 ...
# 1730  [nan, This piece is a response to Coyne’s Dest...
# 465   [To study the complexity of hot Jupiter atmosp...
# 3225  [Scientific investigations have progressively ...
# 838   [The evaluation of changes in Intervertebral D...
# 913   [The evaluation of changes in Intervertebral D...
#
#                                                    urls  \
# 1082  [https://ore.exeter.ac.uk/repository/handle/10...
# 1365  [https://ore.exeter.ac.uk/repository/handle/10...
# 696   [https://ore.exeter.ac.uk/repository/handle/10...
# 1122  [https://ore.exeter.ac.uk/repository/handle/10...
# 2292  [https://ore.exeter.ac.uk/repository/handle/10...
# ...                                                 ...
# 1730  [https://ore.exeter.ac.uk/repository/handle/10...
# 465   [https://ore.exeter.ac.uk/repository/handle/10...
# 3225  [https://ore.exeter.ac.uk/repository/handle/10...
# 838   [https://ore.exeter.ac.uk/repository/handle/10...
# 913   [https://ore.exeter.ac.uk/repository/handle/10...
#
#                                                  fields  \
# 1082                                      [Engineering]
# 1365                                      [Engineering]
# 696                                       [Engineering]
# 1122                                      [Engineering]
# 2292                                      [Biosciences]
# ...                                                 ...
# 1730  [Classics and Ancient History, Classics and An...
# 465   [Physics and Astronomy, Computer Science, Engi...
# 3225  [Institute of Health Research, Institute of Bi...
# 838   [Physics and Astronomy, Computer Science, Engi...
# 913   [Physics and Astronomy, Computer Science, Engi...
#
#                                                   types
# 1082                                          [article]
# 1365                                          [article]
# 696                                           [article]
# 1122                                          [article]
# 2292                                          [article]
# ...                                                 ...
# 1730  [article, article, article, article, article, ...
# 465   [article, article, article, article, article, ...
# 3225  [article, article, article, article, article, ...
# 838   [article, article, article, article, article, ...
# 913   [article, article, article, article, article, ...
#
# [249 rows x 17 columns]

# %%
# Explode the data
df["id"] = df.index
df_long = df.set_index(['id']).apply(pd.Series.explode).reset_index()
df_long.authors = df_long.authors.str.strip('[]')
df_long
# Out:
#          id                                            college  \
# 0         0                                    Business School
# 1         0                                    Business School
# 2         0                                    Business School
# 3         0                                    Business School
# 4         0                                    Business School
# ...     ...                                                ...
# 31137  4135  College of Social Sciences and International S...
# 31138  4136  College of Social Sciences and International S...
# 31139  4137  College of Social Sciences and International S...
# 31140  4138  College of Social Sciences and International S...
# 31141  4139  College of Social Sciences and International S...
#
#                   department                   name  \
# 0                  Economics  Professor Ian Bateman
# 1                  Economics  Professor Ian Bateman
# 2                  Economics  Professor Ian Bateman
# 3                  Economics  Professor Ian Bateman
# 4                  Economics  Professor Ian Bateman
# ...                      ...                    ...
# 31137  Strategy and Security           Tobias Borck
# 31138  Strategy and Security    Maria Chiara Slucca
# 31139  Strategy and Security          Leanne Fuller
# 31140  Strategy and Security         Salem Osseiran
# 31141  Strategy and Security              Noel Trew
#
#                                                     role  \
# 0      Professor of Environmental Economics, Director...
# 1      Professor of Environmental Economics, Director...
# 2      Professor of Environmental Economics, Director...
# 3      Professor of Environmental Economics, Director...
# 4      Professor of Environmental Economics, Director...
# ...                                                  ...
# 31137                                        PhD Student
# 31138                                        PhD Student
# 31139                                        PhD Student
# 31140                                        PhD Student
# 31141                                        PhD Student
#
#                                                  profile  namelast namefirst  \
# 0      https://business-school.exeter.ac.uk/about/peo...   Bateman       Ian
# 1      https://business-school.exeter.ac.uk/about/peo...   Bateman       Ian
# 2      https://business-school.exeter.ac.uk/about/peo...   Bateman       Ian
# 3      https://business-school.exeter.ac.uk/about/peo...   Bateman       Ian
# 4      https://business-school.exeter.ac.uk/about/peo...   Bateman       Ian
# ...                                                  ...       ...       ...
# 31137           http://eprofile.exeter.ac.uk/tobiasborck     Borck    Tobias
# 31138   https://eprofile.exeter.ac.uk/mariachiaraslucca/    Slucca     Maria
# 31139        https://eprofile.exeter.ac.uk/leannefuller/    Fuller    Leanne
# 31140       https://eprofile.exeter.ac.uk/salemosseiran/  Osseiran     Salem
# 31141              http://eprofile.exeter.ac.uk/noeltrew      Trew      Noel
#
#        identifier1      identifier2  publications  \
# 0       bateman, i     bateman, ian            40
# 1       bateman, i     bateman, ian            40
# 2       bateman, i     bateman, ian            40
# 3       bateman, i     bateman, ian            40
# 4       bateman, i     bateman, ian            40
# ...            ...              ...           ...
# 31137     borck, t    borck, tobias             0
# 31138    slucca, m    slucca, maria             0
# 31139    fuller, l   fuller, leanne             0
# 31140  osseiran, s  osseiran, salem             0
# 31141      trew, n       trew, noel             0
#
#                                                  authors       dates  \
# 0                          'Fezzi, Carlo', 'Bateman, IJ'  2015-02-04
# 1      'Bateman, IJ', 'Harwood, Amii R.', 'Mace, Geor...  2013-10-25
# 2             'Bateman, IJ', 'Agarwala, M', "Bad'ura, T"  2014-01-08
# 3      'Bateman, IJ', 'Harwood, Amii R.', 'Mace, Geor...  2013-07-05
# 4      'Bateman, IJ', 'Agarwala, M', 'Binner, A', 'Co...  2016-06-22
# ...                                                  ...         ...
# 31137                                                NaN         NaN
# 31138                                                NaN         NaN
# 31139                                                NaN         NaN
# 31140                                                NaN         NaN
# 31141                                                NaN         NaN
#
#                                                   titles  \
# 0      The Impact of Climate Change on Agriculture: N...
# 1                           Ecosystem services: response
# 2      Pollinator declines: Avoid pitfalls of consens...
# 3      Bringing ecosystem services into economic deci...
# 4      Spatially explicit integrated modeling and eco...
# ...                                                  ...
# 31137                                                NaN
# 31138                                                NaN
# 31139                                                NaN
# 31140                                                NaN
# 31141                                                NaN
#
#                                                abstracts  \
# 0      Ricardian (hedonic) analyses of the impact of ...
# 1                                                    NaN
# 2                                                    NaN
# 3      Landscapes generate a wide range of valuable e...
# 4      We present an integrated model of the direct c...
# ...                                                  ...
# 31137                                                NaN
# 31138                                                NaN
# 31139                                                NaN
# 31140                                                NaN
# 31141                                                NaN
#
#                                                     urls     fields    types
# 0      https://ore.exeter.ac.uk/repository/handle/108...  Economics  article
# 1      https://ore.exeter.ac.uk/repository/handle/108...  Economics  article
# 2      https://ore.exeter.ac.uk/repository/handle/108...  Economics  article
# 3      https://ore.exeter.ac.uk/repository/handle/108...  Economics  article
# 4      https://ore.exeter.ac.uk/repository/handle/108...  Economics  article
# ...                                                  ...        ...      ...
# 31137                                                NaN        NaN      NaN
# 31138                                                NaN        NaN      NaN
# 31139                                                NaN        NaN      NaN
# 31140                                                NaN        NaN      NaN
# 31141                                                NaN        NaN      NaN
#
# [31142 rows x 18 columns]

# %%
# Save/load data
df_long.to_csv('UoE_staff_publications_theses.csv', index = False)
